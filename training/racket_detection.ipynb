# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 74.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 93.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.8 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="6ywfPbjh4Xic8kmSAUpz")
project = rf.workspace("racket").project("racket-x8uin")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Racket-1 in yolov8:: 100%|██████████| 2737/2737 [00:00<00:00, 5765.40it/s]

# %%
rf = Roboflow(api_key="6ywfPbjh4Xic8kmSAUpz")
project = rf.workspace("racket-dataset").project("racket-bkrue")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to racket-4 in yolov8:: 100%|██████████| 776/776 [00:00<00:00, 4735.52it/s]

# %%
from ultralytics import YOLO

# Load pretrained YOLOv8 model
model = YOLO("yolov8n.pt")
# !yolo detect train model=yolov8n.pt data=/content/Racket-1/data.yaml epochs=100 imgsz=640
# Out:
# ...
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# load trained model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# run on TEST folder
results = model.predict(
    source="/content/Racket-1/test/images",
    save=True,
    conf=0.3
)
# Out:
# image 1/80 /content/Racket-1/test/images/10012_jpg.rf.3938da0e73fdfdac4c20365195e3a277.jpg: 640x640 1 0, 9.8ms
# image 2/80 /content/Racket-1/test/images/10050_jpg.rf.e536d0c882e2297bcaa7500f8e1c4476.jpg: 640x640 1 0, 6.6ms
# image 3/80 /content/Racket-1/test/images/10057_jpg.rf.2ad19c6c9b2959eb82d97a7c0876a901.jpg: 640x640 1 0, 5.8ms
# image 4/80 /content/Racket-1/test/images/10069_jpg.rf.d20cd21a19f8f64338be5ac5385144bc.jpg: 640x640 2 0s, 5.9ms
# image 5/80 /content/Racket-1/test/images/10094_jpg.rf.a7de077c7caeb613b9aca9d140b22efa.jpg: 640x640 2 0s, 6.2ms
# image 6/80 /content/Racket-1/test/images/10113_jpg.rf.ad32f5b131138cf78fd7d82cdc29eff2.jpg: 640x640 1 0, 6.4ms
# image 7/80 /content/Racket-1/test/images/10120_jpg.rf.58e94b840b7ca82c6e0fedaa8c7d4272.jpg: 640x640 2 0s, 6.1ms
# image 8/80 /content/Racket-1/test/images/10121_jpg.rf.aa427b856d407b935529b9146f23eb95.jpg: 640x640 2 0s, 6.4ms
# ...
